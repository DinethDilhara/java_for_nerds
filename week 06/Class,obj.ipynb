// %%
%%sh
# Install java kernel
wget -q https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip
unzip -q ijava-1.3.0.zip
python install.py

# Install proxy for the java kernel
wget -qO- https://gist.github.com/SpencerPark/e2732061ad19c1afa4a33a58cb8f18a9/archive/b6cff2bf09b6832344e576ea1e4731f0fb3df10c.tar.gz | tar xvz --strip-components=1
python install_ipc_proxy_kernel.py --kernel=java --implementation=ipc_proxy_kernel.py
// Out:
// Installed java kernel into "/usr/local/share/jupyter/kernels/java"
// e2732061ad19c1afa4a33a58cb8f18a9-b6cff2bf09b6832344e576ea1e4731f0fb3df10c/install_ipc_proxy_kernel.py
// e2732061ad19c1afa4a33a58cb8f18a9-b6cff2bf09b6832344e576ea1e4731f0fb3df10c/ipc_proxy_kernel.py
// Moving java kernel from /usr/local/share/jupyter/kernels/java...
// Wrote modified kernel.json for java_tcp in /usr/local/share/jupyter/kernels/java_tcp/kernel.json
// Installing the proxy kernel in place of java in /usr/local/share/jupyter/kernels/java
// Installed proxy kernelspec: {"argv": ["/usr/bin/python3", "/usr/local/share/jupyter/kernels/java/ipc_proxy_kernel.py", "{connection_file}", "--kernel=java_tcp"], "env": {}, "display_name": "Java", "language": "java", "interrupt_mode": "message", "metadata": {}}
// Proxy kernel installed. Go to 'Runtime > Change runtime type' and select 'java'
// ...

// %%
System.out.println("hello world");
// Out:
// hello world

// %% [markdown]
// # <b><font color="red ">Here we are going to talk about classes and Objects in Java</font></b>
//
//
//
// > - Class & Object
//
// - What is an Object and Properties of an Object
// - What is a Class
// - Classes and Objects: state/data/attributes
// - Adding Variables (Characteristics)
// - Adding Methods (Actions)
// - Creating Objects (Instantiating Objects)
// - Accessing Instance Variables
// - Accessing Instance Methods
// - References to the Same Object
// - Access Modifiers
// - Scope & Visibility Rules Table
// - Access Levels
// - Constructor of a Class
//
//
// ---

// %% [markdown]
// # <font color="Green "><b>  What is Class and Object </b></font>
//
// ##  <font color="red "><u> Object </u></font>
//
// Object is an individual unit which is a real world entity that can be tangibale or untangiable.
//
// Each and every object has their own Attributes and Behaviour.
//
// Attributes describes the Characteristics of the object and Behaviour shows (actions)what it can do.
//
// ##  <font color="red "><u> Class </u></font>
//
// Class is a user define Template/Blueprint/Prototype that create a object and An Object is created as instance of a class.
//
// A class is capable of creating objects many times as per requirement and every object that is created through one class hold same behaviours.
//
// When we decalartion of  class and object class does not allocate any memory but object does
//
// Also class works as user define non-premitive data type (data class) contain with it's attributes

// %% [markdown]
// ![c&o-01.png](data:image/png;base64,...)

// %% [markdown]
// ### <font color ="green" ><b>Attributes in class<b></font>

// %%
/* adding Attributes to class */

public class Person {

    String name;
    String surName;
    String mail;

}

// %% [markdown]
// ### <font color ="green" ><b>Methods in class<b></font>
//
//
// ### </u><b>Constructor<b></u>
//
// There is another special method type in class call `Constructor`
//
// Always and only used with the new operator (keyword) to create an
// instance of a class. -> example : Rectangle r1 = new Rectangle();
//
// it is unqiue to perticular class
//
// Constructor is a special type of method
// - That have no return type
// - It has no return type (NO void || NO retrun data type)
// - If we do not define Constructor, java automatical create Constructor with no parameters and run it defaulty
// - It is a defaultly run in main method without invoking
// - It contains the same name that class name it belongs to.
// - One class can have more than one Constructor but with diffrent parameters bacause otherwise it will cause method overloading.

// %%
public class Person{


// this is defult constructor

public Person(){

    }

// this is  constructor  with parameters

public Person(String name , int age ){
    this.name = name ;
    this.age = age ;
}

}

// %%
// creating object

public class Main{

      public static void main(String[] args){

           Person person = new Person() ; // using defult constructor

           Person person1 = new Person("Dineth",22); // using constructor with parameters

      }

}

// %% [markdown]
// #### <b><u>Getters & Setters<b></u>
//
//
// |                       | Getters                                            | Setters                                            |
// |-----------------------|----------------------------------------------------|----------------------------------------------------|
// | Purpose               | Retrieve the value of a property                   | Set the value of a property                        |
// | Name Convention       | Typically prefixed with "get"                      | Typically prefixed with "set"                      |
// | Return Type           | Returns the value of the property                  | Void (no return value)                             |
// | Parameter             | No parameters                                      | One parameter (the new value)                      |
// | Usage                 | Used to access properties                          | Used to modify properties                          |
// | Example               | `public String getName() { ... }`                   | `public void setName(String name) { ... }`         |
// | Accessibility         | Usually public                                     | Usually public                                     |
// | Encapsulation         | Can be used to implement encapsulation by returning a copy of the property | Used to control access to the property by performing validation or other logic |
// | Additional Purpose    | Used to retrieve the values of private fields from a class | Used to modify the values of private fields in a class |
//
// <br>

// %% [markdown]
// ![Copy-of-SOCKET.png](data:image/png;base64,...)

// %% [markdown]
// ### <font color ="green" ><b>Encapsulation<b></font>
//
// Encapsulation is a mechanism in OOP that wraps attributes, allowing access only within its own class. For this, we use the private access modifier on attributes.
//
// To store and display data, we utilize methods known as getters and setters.
//
// Through setters, data is added using the `this` keyword.
//
// The usage of the `this` keyword helps to avoid self-assigning attributes and parameters in constructors, and instead adds a reference to the properties.

// %%
// Java Encapsulation


class Person {

	private String name;
	private int age;

	public String getName() {
     return name;
     }

	public void setName(String name) {
     this.name = name;
     }

	public int getAge() {
     return age;
     }

	public void setAge(int age) {
     this.age = age;
     }

}

public class Main {

	public static void main(String[] args)
	{
		// person object created
		Person person = new Person();
		person.setName("Dineth");
		person.setAge(22);


		System.out.println("Name: " + person.getName());
		System.out.println("Age: " + person.getAge());
	}
}

// %% [markdown]
// OUTPUT
// ```
// Name: Dineth
// Age: 22
// ```

// %% [markdown]
// ## <font color="Green" >Accessing Instance Variables And Methods</font>
//
// To achieve encapsulation, we add the private keyword to class attributes.
//
// Since these variables and methods aren't static, we access them as instance methods and instance variables.
//
// To do so, we create an object and use its reference variable to access these attributes and methods.

// %%
public class Person (){

        private String name ;
        private int age ;

      public Person(){

      }

      public void setName(String name){
          this.name = name ;
      }

      public void setAge(int age){
          this.age = age ;
      }

      public String getName(){
          return name ;
      }

      public int age(){
          return age ;
      }

}


public class Main{


    public satic void main(String [] args){

        Person person = new Person();

        person.setName("Dineth");
        person.setAge(22)

    }
}
